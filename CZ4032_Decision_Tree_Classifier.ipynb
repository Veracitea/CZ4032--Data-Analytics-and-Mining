# %%
#Importing required libraries
import pandas as pd
import numpy as np
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import export_text
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# ## IRIS

# %%
iris = pd.read_csv('iris.csv')
# iris.head()
X = iris[["sepallength", "petalwidth", "sepalwidth", "petallength"]]
y = iris[["class"]]
cols = ["sepallength", "petalwidth", "sepalwidth", "petallength"]

# %%
#fitting
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 25, test_size = 0.2)
Xt, Xcv, Yt, Ycv = train_test_split(X_train,y_train, random_state = 25, test_size = 0.2)

decision_tree = DecisionTreeClassifier(criterion='gini')

decision_tree = decision_tree.fit(Xt,Yt)
r = export_text(decision_tree, feature_names=cols)
print(r)

#prediction
y_train_pred = decision_tree.predict(X_train)
y_test_pred = decision_tree.predict(X_test)

# Check the Goodness of Fit (on Train Data)
print("Goodness of Fit of Model \tTrain Dataset")
print("Classification Accuracy \t:", decision_tree.score(X_train, y_train))
print()

# Check the Goodness of Fit (on Test Data)
print("Goodness of Fit of Model \tTest Dataset")
print("Classification Accuracy \t:", decision_tree.score(X_test, y_test))
print()
# Out:
# |--- sepalwidth <= 2.45
# |   |--- class: Iris-setosa
# |--- sepalwidth >  2.45
# |   |--- petallength <= 1.75
# |   |   |--- sepalwidth <= 5.35
# |   |   |   |--- sepallength <= 4.95
# |   |   |   |   |--- petalwidth <= 2.45
# |   |   |   |   |   |--- class: Iris-versicolor
# |   |   |   |   |--- petalwidth >  2.45
# |   |   |   |   |   |--- class: Iris-virginica
# |   |   |   |--- sepallength >  4.95
# |   |   |   |   |--- class: Iris-versicolor
# |   |   |--- sepalwidth >  5.35
# |   |   |   |--- class: Iris-virginica
# |   |--- petallength >  1.75
# |   |   |--- class: Iris-virginica
#
# Goodness of Fit of Model 	Train Dataset
# Classification Accuracy 	: 0.9916666666666667
#
# Goodness of Fit of Model 	Test Dataset
# Classification Accuracy 	: 0.9333333333333333

# %%
#f1 score:
# print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_test_pred))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00         9
# Iris-versicolor       0.92      0.92      0.92        13
#  Iris-virginica       0.88      0.88      0.88         8
#
#        accuracy                           0.93        30
#       macro avg       0.93      0.93      0.93        30
#    weighted avg       0.93      0.93      0.93        30

# %% [markdown]
# ## WAVEFORM

# %%
wave = pd.read_csv('wave.csv', sep=',')
wave.head()
# Out:
#      x0    x1    x2    x3    x4    x5    x6    x7    x8    x9  ...   x12  \
# 0 -1.23 -1.56 -1.75 -0.28  0.60  2.22  0.85  0.21 -0.20  0.89  ...  2.89
# 1 -0.69  2.43  0.61  2.08  2.30  3.25  5.52  4.55  2.97  2.22  ...  1.24
# 2 -0.12 -0.94  1.29  2.59  2.42  3.55  4.94  3.25  1.90  2.07  ...  2.50
# 3  0.86  0.29  2.19 -0.02  1.13  2.51  2.37  5.45  5.45  4.84  ...  2.58
# 4  1.16  0.37  0.40 -0.59  2.66  1.00  2.69  4.06  5.34  3.53  ...  4.30
#
#     x13   x14   x15   x16   x17   x18   x19   x20  class
# 0  7.75  4.59  3.15  5.12  3.32  1.20  0.24 -0.56      2
# 1  1.89  1.88 -1.34  0.83  1.41  1.78  0.60  2.42      1
# 2  0.12  1.41  2.78  0.64  0.62 -0.01 -0.79 -0.12      0
# 3  1.40  1.24  1.41  1.07 -1.43  2.84 -1.18  1.12      1
# 4  1.84  1.73  0.21 -0.18  0.13 -0.21 -0.80 -0.68      1
#
# [5 rows x 22 columns]

# %%
X = wave[['x0','x1',	'x2',	'x3',	'x4',	'x5',	'x6',	'x7',	'x8',	'x9',	'x10',	'x11'	,'x12','x13',	'x14',	'x15',	'x16',	'x17',	'x18',	'x19',	'x20']]
y = wave[['class']]
cols = ['x0','x1',	'x2',	'x3',	'x4',	'x5',	'x6',	'x7',	'x8',	'x9',	'x10',	'x11'	,'x12','x13',	'x14',	'x15',	'x16',	'x17',	'x18',	'x19',	'x20']

# %%
#fitting
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 25, test_size = 0.2)

Xt, Xcv, Yt, Ycv = train_test_split(X_train,y_train, random_state = 25, test_size = 0.2)

decision_tree = DecisionTreeClassifier(criterion='gini')

decision_tree = decision_tree.fit(Xt,Yt)
r = export_text(decision_tree, feature_names=cols)
print(r)

#prediction
y_train_pred = decision_tree.predict(X_train)
y_test_pred = decision_tree.predict(X_test)

# Check the Goodness of Fit (on Train Data)
print("Goodness of Fit of Model \tTrain Dataset")
print("Classification Accuracy \t:", decision_tree.score(X_train, y_train))
print()

# Check the Goodness of Fit (on Test Data)
print("Goodness of Fit of Model \tTest Dataset")
print("Classification Accuracy \t:", decision_tree.score(X_test, y_test))
print()
# Out:
# |--- x6 <= 2.56
# |   |--- x11 <= 2.69
# |   |   |--- x12 <= 3.64
# |   |   |   |--- x10 <= 3.59
# |   |   |   |   |--- x5 <= 0.20
# |   |   |   |   |   |--- x10 <= 1.44
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- x10 >  1.44
# |   |   |   |   |   |   |--- x9 <= 1.63
# |   |   |   |   |   |   |   |--- x13 <= 5.09
# |   |   |   |   |   |   |   |   |--- x1 <= -0.86
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- x1 >  -0.86
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- x13 >  5.09
# |   |   |   |   |   |   |   |   |--- x17 <= 1.36
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- x17 >  1.36
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |--- x9 >  1.63
# |   |   |   |   |   |   |   |--- x4 <= 1.44
# |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- x4 >  1.44
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- x5 >  0.20
# |   |   |   |   |   |--- x6 <= 0.16
# |   |   |   |   |   |   |--- x16 <= 3.82
# |   |   |   |   |   |   |   |--- x16 <= 2.14
# |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- x16 >  2.14
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- x16 >  3.82
# |   |   |   |   |   |   |   |--- x18 <= 2.13
# |   |   |   |   |   |   |   |   |--- x19 <= 2.39
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- x19 >  2.39
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- x18 >  2.13
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- x6 >  0.16
# |   |   |   |   |   |   |--- x3 <= -0.70
# |   |   |   |   |   |   |   |--- x16 <= 3.42
# |   |   |   |   |   |   |   |   |--- x11 <= 1.15
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- x11 >  1.15
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- x16 >  3.42
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- x3 >  -0.70
# |   |   |   |   |   |   |   |--- x13 <= 5.66
# |   |   |   |   |   |   |   |   |--- x2 <= -0.87
# |   |   |   |   |   |   |   |   |   |--- x2 <= -0.89
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- x2 >  -0.89
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- x2 >  -0.87
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- x13 >  5.66
# |   |   |   |   |   |   |   |   |--- x7 <= 1.02
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- x7 >  1.02
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |--- x10 >  3.59
# |   |   |   |   |--- x7 <= 3.10
# |   |   |   |   |   |--- x3 <= 0.60
# |   |   |   |   |   |   |--- x8 <= 0.15
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- x8 >  0.15
# |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |--- x3 >  0.60
# |   |   |   |   |   |   |--- x9 <= 3.36
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- x9 >  3.36
# |   |   |   |   |   |   |   |--- x13 <= 3.55
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- x13 >  3.55
# |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |--- x7 >  3.10
# |   |   |   |   |   |--- class: 1
# |   |   |--- x12 >  3.64
# |   |   |   |--- x10 <= 2.07
# |   |   |   |   |--- x6 <= -0.26
# |   |   |   |   |   |--- x11 <= 2.11
# |   |   |   |   |   |   |--- x13 <= 5.01
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- x13 >  5.01
# |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |--- x11 >  2.11
# |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |--- x6 >  -0.26
# |   |   |   |   |   |--- x19 <= -0.70
# |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |--- x19 >  -0.70
# |   |   |   |   |   |   |--- x17 <= 4.34
# |   |   |   |   |   |   |   |--- x15 <= 2.32
# |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- x15 >  2.32
# |   |   |   |   |   |   |   |   |--- x12 <= 6.05
# |   |   |   |   |   |   |   |   |   |--- x19 <= 2.63
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- x19 >  2.63
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- x12 >  6.05
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |--- x17 >  4.34
# |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |--- x10 >  2.07
# |   |   |   |   |--- x4 <= 0.16
# |   |   |   |   |   |--- x9 <= 1.65
# |   |   |   |   |   |   |--- x2 <= -0.38
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- x2 >  -0.38
# |   |   |   |   |   |   |   |--- x0 <= -0.56
# |   |   |   |   |   |   |   |   |--- x14 <= 5.63
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- x14 >  5.63
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- x0 >  -0.56
# |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |--- x9 >  1.65
# |   |   |   |   |   |   |--- x17 <= -0.77
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- x17 >  -0.77
# |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |--- x4 >  0.16
# |   |   |   |   |   |--- x11 <= 1.86
# |   |   |   |   |   |   |--- x14 <= 4.14
# |   |   |   |   |   |   |   |--- x1 <= 1.45
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- x1 >  1.45
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- x14 >  4.14
# |   |   |   |   |   |   |   |--- x9 <= 1.44
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- x9 >  1.44
# |   |   |   |   |   |   |   |   |--- x20 <= -1.87
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- x20 >  -1.87
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |--- x11 >  1.86
# |   |   |   |   |   |   |--- x4 <= 0.24
# |   |   |   |   |   |   |   |--- x3 <= 1.31
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- x3 >  1.31
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- x4 >  0.24
# |   |   |   |   |   |   |   |--- x14 <= 5.49
# |   |   |   |   |   |   |   |   |--- x14 <= 1.44
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- x14 >  1.44
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- x14 >  5.49
# |   |   |   |   |   |   |   |   |--- x20 <= 0.67
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- x20 >  0.67
# |   |   |   |   |   |   |   |   |   |--- x11 <= 2.38
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- x11 >  2.38
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |--- x11 >  2.69
# |   |   |--- x14 <= 2.25
# |   |   |   |--- x17 <= 0.04
# |   |   |   |   |--- x5 <= 0.94
# |   |   |   |   |   |--- x7 <= 3.59
# |   |   |   |   |   |   |--- x4 <= 0.69
# |   |   |   |   |   |   |   |--- x19 <= -0.09
# |   |   |   |   |   |   |   |   |--- x7 <= 2.00
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- x7 >  2.00
# |   |   |   |   |   |   |   |   |   |--- x1 <= 1.19
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- x1 >  1.19
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- x19 >  -0.09
# |   |   |   |   |   |   |   |   |--- x15 <= -0.83
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- x15 >  -0.83
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |--- x4 >  0.69
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- x7 >  3.59
# |   |   |   |   |   |   |--- x20 <= -2.25
# |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |--- x20 >  -2.25
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- x5 >  0.94
# |   |   |   |   |   |--- x4 <= -1.39
# |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |--- x4 >  -1.39
# |   |   |   |   |   |   |--- x9 <= 0.66
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- x9 >  0.66
# |   |   |   |   |   |   |   |--- x13 <= 5.62
# |   |   |   |   |   |   |   |   |--- x16 <= -2.39
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- x16 >  -2.39
# |   |   |   |   |   |   |   |   |   |--- x8 <= 5.84
# |   |   |   |   |   |   |   |   |   |   |--- x16 <= 0.37
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- x16 >  0.37
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |--- x8 >  5.84
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- x13 >  5.62
# |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |--- x17 >  0.04
# |   |   |   |   |--- x13 <= 2.47
# |   |   |   |   |   |--- x6 <= 1.22
# |   |   |   |   |   |   |--- x19 <= -1.59
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- x19 >  -1.59
# |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |--- x6 >  1.22
# |   |   |   |   |   |   |--- x15 <= 2.73
# |   |   |   |   |   |   |   |--- x10 <= 2.92
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- x10 >  2.92
# |   |   |   |   |   |   |   |   |--- x10 <= 7.23
# |   |   |   |   |   |   |   |   |   |--- x16 <= 1.64
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- x16 >  1.64
# |   |   |   |   |   |   |   |   |   |   |--- x16 <= 1.85
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |   |--- x16 >  1.85
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- x10 >  7.23
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |--- x15 >  2.73
# |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |--- x13 >  2.47
# |   |   |   |   |   |--- x16 <= -0.02
# |   |   |   |   |   |   |--- x7 <= 1.88
# |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |--- x7 >  1.88
# |   |   |   |   |   |   |   |--- x6 <= 2.40
# |   |   |   |   |   |   |   |   |--- x8 <= 2.08
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- x8 >  2.08
# |   |   |   |   |   |   |   |   |   |--- x0 <= 0.88
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- x0 >  0.88
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- x6 >  2.40
# |   |   |   |   |   |   |   |   |--- x14 <= 1.86
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- x14 >  1.86
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- x16 >  -0.02
# |   |   |   |   |   |   |--- x16 <= 2.88
# |   |   |   |   |   |   |   |--- x10 <= 3.69
# |   |   |   |   |   |   |   |   |--- x13 <= 3.45
# |   |   |   |   |   |   |   |   |   |--- x11 <= 3.70
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- x11 >  3.70
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- x13 >  3.45
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- x10 >  3.69
# |   |   |   |   |   |   |   |   |--- x0 <= 2.93
# |   |   |   |   |   |   |   |   |   |--- x10 <= 8.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |--- x10 >  8.00
# |   |   |   |   |   |   |   |   |   |   |--- x13 <= 3.38
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- x13 >  3.38
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- x0 >  2.93
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- x16 >  2.88
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |--- x14 >  2.25
# |   |   |   |--- x10 <= 2.32
# |   |   |   |   |--- x6 <= 1.45
# |   |   |   |   |   |--- x3 <= 0.80
# |   |   |   |   |   |   |--- x11 <= 3.99
# |   |   |   |   |   |   |   |--- x4 <= 0.25
# |   |   |   |   |   |   |   |   |--- x2 <= -1.75
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- x2 >  -1.75
# |   |   |   |   |   |   |   |   |   |--- x2 <= 1.38
# |   |   |   |   |   |   |   |   |   |   |--- x5 <= 2.28
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- x5 >  2.28
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- x2 >  1.38
# |   |   |   |   |   |   |   |   |   |   |--- x17 <= 1.72
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |   |--- x17 >  1.72
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- x4 >  0.25
# |   |   |   |   |   |   |   |   |--- x20 <= 0.16
# |   |   |   |   |   |   |   |   |   |--- x4 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- x14 <= 5.24
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- x14 >  5.24
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- x4 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- x20 <= -2.07
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- x20 >  -2.07
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- x20 >  0.16
# |   |   |   |   |   |   |   |   |   |--- x12 <= 4.17
# |   |   |   |   |   |   |   |   |   |   |--- x11 <= 3.95
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- x11 >  3.95
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |--- x12 >  4.17
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |--- x11 >  3.99
# |   |   |   |   |   |   |   |--- x18 <= -0.57
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- x18 >  -0.57
# |   |   |   |   |   |   |   |   |--- x1 <= -1.80
# |   |   |   |   |   |   |   |   |   |--- x8 <= 1.72
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |--- x8 >  1.72
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- x1 >  -1.80
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |--- x3 >  0.80
# |   |   |   |   |   |   |--- x3 <= 1.40
# |   |   |   |   |   |   |   |--- x5 <= -0.85
# |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- x5 >  -0.85
# |   |   |   |   |   |   |   |   |--- x5 <= 2.43
# |   |   |   |   |   |   |   |   |   |--- x4 <= -0.02
# |   |   |   |   |   |   |   |   |   |   |--- x0 <= -0.62
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |   |--- x0 >  -0.62
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- x4 >  -0.02
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- x5 >  2.43
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |--- x3 >  1.40
# |   |   |   |   |   |   |   |--- x5 <= 1.28
# |   |   |   |   |   |   |   |   |--- x8 <= 2.30
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- x8 >  2.30
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- x5 >  1.28
# |   |   |   |   |   |   |   |   |--- x2 <= -0.97
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- x2 >  -0.97
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- x6 >  1.45
# |   |   |   |   |   |--- x3 <= -0.62
# |   |   |   |   |   |   |--- x11 <= 3.15
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- x11 >  3.15
# |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |--- x3 >  -0.62
# |   |   |   |   |   |   |--- x5 <= -0.10
# |   |   |   |   |   |   |   |--- x18 <= 1.55
# |   |   |   |   |   |   |   |   |--- x8 <= 2.20
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- x8 >  2.20
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- x18 >  1.55
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- x5 >  -0.10
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |--- x10 >  2.32
# |   |   |   |   |--- x7 <= 2.91
# |   |   |   |   |   |--- x9 <= 0.25
# |   |   |   |   |   |   |--- x10 <= 2.90
# |   |   |   |   |   |   |   |--- x4 <= -0.02
# |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- x4 >  -0.02
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- x10 >  2.90
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- x9 >  0.25
# |   |   |   |   |   |   |--- x12 <= 1.81
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- x12 >  1.81
# |   |   |   |   |   |   |   |--- x8 <= 0.63
# |   |   |   |   |   |   |   |   |--- x4 <= 0.42
# |   |   |   |   |   |   |   |   |   |--- x13 <= 5.75
# |   |   |   |   |   |   |   |   |   |   |--- x5 <= 1.61
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- x5 >  1.61
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- x13 >  5.75
# |   |   |   |   |   |   |   |   |   |   |--- x17 <= 2.30
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |   |--- x17 >  2.30
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- x4 >  0.42
# |   |   |   |   |   |   |   |   |   |--- x17 <= 2.59
# |   |   |   |   |   |   |   |   |   |   |--- x7 <= 1.82
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- x7 >  1.82
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |--- x17 >  2.59
# |   |   |   |   |   |   |   |   |   |   |--- x20 <= 0.78
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- x20 >  0.78
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- x8 >  0.63
# |   |   |   |   |   |   |   |   |--- x9 <= 6.62
# |   |   |   |   |   |   |   |   |   |--- x16 <= -0.49
# |   |   |   |   |   |   |   |   |   |   |--- x3 <= 1.02
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- x3 >  1.02
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- x16 >  -0.49
# |   |   |   |   |   |   |   |   |   |   |--- x17 <= -2.45
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- x17 >  -2.45
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 12
# |   |   |   |   |   |   |   |   |--- x9 >  6.62
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- x7 >  2.91
# |   |   |   |   |   |--- x15 <= 1.90
# |   |   |   |   |   |   |--- x16 <= 0.91
# |   |   |   |   |   |   |   |--- x8 <= 2.29
# |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- x8 >  2.29
# |   |   |   |   |   |   |   |   |--- x2 <= 1.85
# |   |   |   |   |   |   |   |   |   |--- x10 <= 6.76
# |   |   |   |   |   |   |   |   |   |   |--- x13 <= 3.86
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- x13 >  3.86
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- x10 >  6.76
# |   |   |   |   |   |   |   |   |   |   |--- x11 <= 5.43
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |   |--- x11 >  5.43
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- x2 >  1.85
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |--- x16 >  0.91
# |   |   |   |   |   |   |   |--- x13 <= 1.96
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- x13 >  1.96
# |   |   |   |   |   |   |   |   |--- x11 <= 6.72
# |   |   |   |   |   |   |   |   |   |--- x20 <= 1.63
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |--- x20 >  1.63
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- x11 >  6.72
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- x15 >  1.90
# |   |   |   |   |   |   |--- x12 <= 2.49
# |   |   |   |   |   |   |   |--- x6 <= 1.31
# |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- x6 >  1.31
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- x12 >  2.49
# |   |   |   |   |   |   |   |--- x19 <= 2.07
# |   |   |   |   |   |   |   |   |--- x13 <= 1.50
# |   |   |   |   |   |   |   |   |   |--- x4 <= 0.09
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |--- x4 >  0.09
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- x13 >  1.50
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- x19 >  2.07
# |   |   |   |   |   |   |   |   |--- x7 <= 4.26
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- x7 >  4.26
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |--- x6 >  2.56
# |   |--- x10 <= 3.00
# |   |   |--- x8 <= 3.26
# |   |   |   |--- x17 <= -0.03
# |   |   |   |   |--- x16 <= 0.94
# |   |   |   |   |   |--- x12 <= -0.41
# |   |   |   |   |   |   |--- x13 <= -0.91
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- x13 >  -0.91
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- x12 >  -0.41
# |   |   |   |   |   |   |--- x15 <= 1.34
# |   |   |   |   |   |   |   |--- x10 <= 2.89
# |   |   |   |   |   |   |   |   |--- x20 <= -0.99
# |   |   |   |   |   |   |   |   |   |--- x17 <= -0.04
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- x17 >  -0.04
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- x20 >  -0.99
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- x10 >  2.89
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- x15 >  1.34
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- x16 >  0.94
# |   |   |   |   |   |--- x11 <= 3.18
# |   |   |   |   |   |   |--- x2 <= -0.37
# |   |   |   |   |   |   |   |--- x1 <= 0.93
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- x1 >  0.93
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- x2 >  -0.37
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- x11 >  3.18
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |--- x17 >  -0.03
# |   |   |   |   |--- x11 <= 4.92
# |   |   |   |   |   |--- x8 <= 2.84
# |   |   |   |   |   |   |--- x5 <= -0.36
# |   |   |   |   |   |   |   |--- x1 <= 0.67
# |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- x1 >  0.67
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- x5 >  -0.36
# |   |   |   |   |   |   |   |--- x17 <= 4.85
# |   |   |   |   |   |   |   |   |--- x4 <= 5.30
# |   |   |   |   |   |   |   |   |   |--- x9 <= 4.12
# |   |   |   |   |   |   |   |   |   |   |--- x14 <= -0.87
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- x14 >  -0.87
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- x9 >  4.12
# |   |   |   |   |   |   |   |   |   |   |--- x10 <= 2.80
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- x10 >  2.80
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- x4 >  5.30
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- x17 >  4.85
# |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |--- x8 >  2.84
# |   |   |   |   |   |   |--- x16 <= -0.21
# |   |   |   |   |   |   |   |--- x18 <= 0.72
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- x18 >  0.72
# |   |   |   |   |   |   |   |   |--- x0 <= 1.12
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- x0 >  1.12
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- x16 >  -0.21
# |   |   |   |   |   |   |   |--- x10 <= 2.19
# |   |   |   |   |   |   |   |   |--- x1 <= -1.33
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- x1 >  -1.33
# |   |   |   |   |   |   |   |   |   |--- x4 <= 1.33
# |   |   |   |   |   |   |   |   |   |   |--- x20 <= -0.03
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- x20 >  -0.03
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- x4 >  1.33
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- x10 >  2.19
# |   |   |   |   |   |   |   |   |--- x3 <= 3.04
# |   |   |   |   |   |   |   |   |   |--- x6 <= 5.50
# |   |   |   |   |   |   |   |   |   |   |--- x9 <= 4.02
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- x9 >  4.02
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- x6 >  5.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- x3 >  3.04
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- x11 >  4.92
# |   |   |   |   |   |--- class: 2
# |   |   |--- x8 >  3.26
# |   |   |   |--- x9 <= 3.20
# |   |   |   |   |--- x14 <= 1.14
# |   |   |   |   |   |--- x4 <= 2.90
# |   |   |   |   |   |   |--- x16 <= 1.03
# |   |   |   |   |   |   |   |--- x6 <= 6.90
# |   |   |   |   |   |   |   |   |--- x18 <= -1.31
# |   |   |   |   |   |   |   |   |   |--- x9 <= 2.53
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- x9 >  2.53
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- x18 >  -1.31
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- x6 >  6.90
# |   |   |   |   |   |   |   |   |--- x17 <= -0.69
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- x17 >  -0.69
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- x16 >  1.03
# |   |   |   |   |   |   |   |--- x0 <= -0.12
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- x0 >  -0.12
# |   |   |   |   |   |   |   |   |--- x1 <= 0.72
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- x1 >  0.72
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- x4 >  2.90
# |   |   |   |   |   |   |--- x12 <= -0.00
# |   |   |   |   |   |   |   |--- x9 <= 3.05
# |   |   |   |   |   |   |   |   |--- x3 <= 1.40
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- x3 >  1.40
# |   |   |   |   |   |   |   |   |   |--- x8 <= 5.51
# |   |   |   |   |   |   |   |   |   |   |--- x14 <= -1.34
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- x14 >  -1.34
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- x8 >  5.51
# |   |   |   |   |   |   |   |   |   |   |--- x3 <= 3.65
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- x3 >  3.65
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- x9 >  3.05
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- x12 >  -0.00
# |   |   |   |   |   |   |   |--- x19 <= -0.30
# |   |   |   |   |   |   |   |   |--- x18 <= 1.12
# |   |   |   |   |   |   |   |   |   |--- x10 <= 1.32
# |   |   |   |   |   |   |   |   |   |   |--- x0 <= -0.91
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- x0 >  -0.91
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- x10 >  1.32
# |   |   |   |   |   |   |   |   |   |   |--- x17 <= -1.17
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- x17 >  -1.17
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- x18 >  1.12
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- x19 >  -0.30
# |   |   |   |   |   |   |   |   |--- x8 <= 5.09
# |   |   |   |   |   |   |   |   |   |--- x1 <= 0.78
# |   |   |   |   |   |   |   |   |   |   |--- x17 <= 0.47
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- x17 >  0.47
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- x1 >  0.78
# |   |   |   |   |   |   |   |   |   |   |--- x11 <= 0.43
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- x11 >  0.43
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- x8 >  5.09
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- x14 >  1.14
# |   |   |   |   |   |--- x4 <= 4.56
# |   |   |   |   |   |   |--- x10 <= 2.75
# |   |   |   |   |   |   |   |--- x18 <= -0.88
# |   |   |   |   |   |   |   |   |--- x0 <= -0.53
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- x0 >  -0.53
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- x18 >  -0.88
# |   |   |   |   |   |   |   |   |--- x11 <= -0.63
# |   |   |   |   |   |   |   |   |   |--- x2 <= 2.35
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- x2 >  2.35
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- x11 >  -0.63
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- x10 >  2.75
# |   |   |   |   |   |   |   |--- x9 <= 1.78
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- x9 >  1.78
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- x4 >  4.56
# |   |   |   |   |   |   |--- x15 <= 0.99
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- x15 >  0.99
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |--- x9 >  3.20
# |   |   |   |   |--- x11 <= 0.59
# |   |   |   |   |   |--- x19 <= 0.41
# |   |   |   |   |   |   |--- x12 <= 1.38
# |   |   |   |   |   |   |   |--- x4 <= 2.15
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- x4 >  2.15
# |   |   |   |   |   |   |   |   |--- x16 <= -0.98
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- x16 >  -0.98
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- x12 >  1.38
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- x19 >  0.41
# |   |   |   |   |   |   |--- x13 <= -0.69
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- x13 >  -0.69
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- x11 >  0.59
# |   |   |   |   |   |--- x16 <= 2.27
# |   |   |   |   |   |   |--- x15 <= 1.98
# |   |   |   |   |   |   |   |--- x4 <= 3.39
# |   |   |   |   |   |   |   |   |--- x10 <= 0.49
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- x10 >  0.49
# |   |   |   |   |   |   |   |   |   |--- x5 <= 6.22
# |   |   |   |   |   |   |   |   |   |   |--- x2 <= 3.60
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- x2 >  3.60
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- x5 >  6.22
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- x4 >  3.39
# |   |   |   |   |   |   |   |   |--- x4 <= 3.45
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- x4 >  3.45
# |   |   |   |   |   |   |   |   |   |--- x7 <= 2.81
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- x7 >  2.81
# |   |   |   |   |   |   |   |   |   |   |--- x11 <= 0.85
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- x11 >  0.85
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |--- x15 >  1.98
# |   |   |   |   |   |   |   |--- x15 <= 2.20
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- x15 >  2.20
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- x16 >  2.27
# |   |   |   |   |   |   |--- class: 0
# |   |--- x10 >  3.00
# |   |   |--- x5 <= 1.14
# |   |   |   |--- x12 <= 3.57
# |   |   |   |   |--- x13 <= 3.15
# |   |   |   |   |   |--- x8 <= 1.78
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- x8 >  1.78
# |   |   |   |   |   |   |--- x3 <= -0.50
# |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |--- x3 >  -0.50
# |   |   |   |   |   |   |   |--- x5 <= 1.11
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- x5 >  1.11
# |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |--- x13 >  3.15
# |   |   |   |   |   |--- x7 <= 3.37
# |   |   |   |   |   |   |--- x12 <= 2.06
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- x12 >  2.06
# |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |--- x7 >  3.37
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |--- x12 >  3.57
# |   |   |   |   |--- x15 <= -0.15
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- x15 >  -0.15
# |   |   |   |   |   |--- x4 <= 1.42
# |   |   |   |   |   |   |--- x13 <= 5.37
# |   |   |   |   |   |   |   |--- x3 <= 1.57
# |   |   |   |   |   |   |   |   |--- x0 <= -1.87
# |   |   |   |   |   |   |   |   |   |--- x6 <= 3.14
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- x6 >  3.14
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- x0 >  -1.87
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- x3 >  1.57
# |   |   |   |   |   |   |   |   |--- x8 <= 4.99
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- x8 >  4.99
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |--- x13 >  5.37
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- x4 >  1.42
# |   |   |   |   |   |   |--- x15 <= 1.72
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- x15 >  1.72
# |   |   |   |   |   |   |   |--- x0 <= -0.15
# |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- x0 >  -0.15
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |--- x5 >  1.14
# |   |   |   |--- x9 <= 2.20
# |   |   |   |   |--- x14 <= 1.28
# |   |   |   |   |   |--- x15 <= 2.14
# |   |   |   |   |   |   |--- x19 <= -1.29
# |   |   |   |   |   |   |   |--- x18 <= -1.26
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- x18 >  -1.26
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- x19 >  -1.29
# |   |   |   |   |   |   |   |--- x3 <= 3.85
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- x3 >  3.85
# |   |   |   |   |   |   |   |   |--- x15 <= -0.04
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- x15 >  -0.04
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- x15 >  2.14
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- x14 >  1.28
# |   |   |   |   |   |--- x10 <= 4.91
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- x10 >  4.91
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |--- x9 >  2.20
# |   |   |   |   |--- x14 <= 3.25
# |   |   |   |   |   |--- x12 <= -0.06
# |   |   |   |   |   |   |--- x7 <= 4.65
# |   |   |   |   |   |   |   |--- x9 <= 4.16
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- x9 >  4.16
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- x7 >  4.65
# |   |   |   |   |   |   |   |--- x3 <= 3.37
# |   |   |   |   |   |   |   |   |--- x8 <= 5.43
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- x8 >  5.43
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- x3 >  3.37
# |   |   |   |   |   |   |   |   |--- x12 <= -0.52
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- x12 >  -0.52
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- x12 >  -0.06
# |   |   |   |   |   |   |--- x16 <= 1.25
# |   |   |   |   |   |   |   |--- x4 <= 0.07
# |   |   |   |   |   |   |   |   |--- x12 <= 4.27
# |   |   |   |   |   |   |   |   |   |--- x9 <= 3.15
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |--- x9 >  3.15
# |   |   |   |   |   |   |   |   |   |   |--- x5 <= 1.18
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |   |--- x5 >  1.18
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- x12 >  4.27
# |   |   |   |   |   |   |   |   |   |--- x16 <= -0.80
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- x16 >  -0.80
# |   |   |   |   |   |   |   |   |   |   |--- x2 <= -1.18
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- x2 >  -1.18
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- x4 >  0.07
# |   |   |   |   |   |   |   |   |--- x5 <= 5.77
# |   |   |   |   |   |   |   |   |   |--- x13 <= 5.51
# |   |   |   |   |   |   |   |   |   |   |--- x11 <= 0.74
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- x11 >  0.74
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |--- x13 >  5.51
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- x5 >  5.77
# |   |   |   |   |   |   |   |   |   |--- x1 <= 0.98
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- x1 >  0.98
# |   |   |   |   |   |   |   |   |   |   |--- x12 <= 1.35
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- x12 >  1.35
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- x16 >  1.25
# |   |   |   |   |   |   |   |--- x11 <= 1.80
# |   |   |   |   |   |   |   |   |--- x7 <= 5.45
# |   |   |   |   |   |   |   |   |   |--- x8 <= 5.23
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- x8 >  5.23
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- x7 >  5.45
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- x11 >  1.80
# |   |   |   |   |   |   |   |   |--- x12 <= 3.47
# |   |   |   |   |   |   |   |   |   |--- x9 <= 2.43
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- x9 >  2.43
# |   |   |   |   |   |   |   |   |   |   |--- x2 <= 2.88
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- x2 >  2.88
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- x12 >  3.47
# |   |   |   |   |   |   |   |   |   |--- x16 <= 1.65
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |--- x16 >  1.65
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- x14 >  3.25
# |   |   |   |   |   |--- x11 <= 3.36
# |   |   |   |   |   |   |--- x8 <= 3.82
# |   |   |   |   |   |   |   |--- x0 <= -0.95
# |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- x0 >  -0.95
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- x8 >  3.82
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- x11 >  3.36
# |   |   |   |   |   |   |--- class: 2
#
# Goodness of Fit of Model 	Train Dataset
# Classification Accuracy 	: 0.95075
#
# Goodness of Fit of Model 	Test Dataset
# Classification Accuracy 	: 0.741

# %%
#f1 score:
# print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.69      0.70      0.69       329
#            1       0.74      0.74      0.74       331
#            2       0.80      0.78      0.79       340
#
#     accuracy                           0.74      1000
#    macro avg       0.74      0.74      0.74      1000
# weighted avg       0.74      0.74      0.74      1000

# %% [markdown]
# ## BREAST CANCER

# %%
#Load the breast cancer dataset
breastCancer = pd.read_csv("breastCancer.csv")
breastCancer.columns=["class","age", "menopause", "tumor-size", "inv-nodes", "node-caps","deg-malig","breast","breast-quad","irradiat"]
breastCancer.to_csv("breastCancer.txt", index = None, header = True)
#wave.to_csv("breastCancer.csv", index = None, header = True)

# %%
labelencoder = LabelEncoder()
# Assigning numerical values and storing in another column
breastCancer['age'] = labelencoder.fit_transform(breastCancer['age'])
breastCancer['menopause'] = labelencoder.fit_transform(breastCancer['menopause'])
breastCancer['tumor-size'] = labelencoder.fit_transform(breastCancer['tumor-size'])
breastCancer['inv-nodes'] = labelencoder.fit_transform(breastCancer['inv-nodes'])
breastCancer['node-caps'] = labelencoder.fit_transform(breastCancer['node-caps'])
breastCancer['breast'] = labelencoder.fit_transform(breastCancer['breast'])
breastCancer['breast-quad'] = labelencoder.fit_transform(breastCancer['breast-quad'])
breastCancer['irradiat'] = labelencoder.fit_transform(breastCancer['irradiat'])

# %%
X = breastCancer[["age", "menopause", "tumor-size", "inv-nodes", "node-caps","deg-malig","breast","breast-quad","irradiat"]]
y = breastCancer[['class']]
cols = ["age", "menopause", "tumor-size", "inv-nodes", "node-caps","deg-malig","breast","breast-quad","irradiat"]

# %%
#fitting
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 25, test_size = 0.2)

Xt, Xcv, Yt, Ycv = train_test_split(X_train,y_train, random_state = 25, test_size = 0.2)

decision_tree = DecisionTreeClassifier(criterion='gini')

decision_tree = decision_tree.fit(Xt,Yt)
r = export_text(decision_tree, feature_names=cols)
print(r)

#prediction
y_train_pred = decision_tree.predict(X_train)
y_test_pred = decision_tree.predict(X_test)

# Check the Goodness of Fit (on Train Data)
print("Goodness of Fit of Model \tTrain Dataset")
print("Classification Accuracy \t:", decision_tree.score(X_train, y_train))
print()

# Check the Goodness of Fit (on Test Data)
print("Goodness of Fit of Model \tTest Dataset")
print("Classification Accuracy \t:", decision_tree.score(X_test, y_test))
print()
# Out:
# |--- deg-malig <= 2.50
# |   |--- tumor-size <= 1.50
# |   |   |--- class: no-recurrence-events
# |   |--- tumor-size >  1.50
# |   |   |--- tumor-size <= 6.50
# |   |   |   |--- deg-malig <= 1.50
# |   |   |   |   |--- node-caps <= 0.50
# |   |   |   |   |   |--- breast <= 0.50
# |   |   |   |   |   |   |--- class: recurrence-events
# |   |   |   |   |   |--- breast >  0.50
# |   |   |   |   |   |   |--- class: no-recurrence-events
# |   |   |   |   |--- node-caps >  0.50
# |   |   |   |   |   |--- age <= 1.50
# |   |   |   |   |   |   |--- breast <= 0.50
# |   |   |   |   |   |   |   |--- class: no-recurrence-events
# |   |   |   |   |   |   |--- breast >  0.50
# |   |   |   |   |   |   |   |--- class: recurrence-events
# |   |   |   |   |   |--- age >  1.50
# |   |   |   |   |   |   |--- class: no-recurrence-events
# |   |   |   |--- deg-malig >  1.50
# |   |   |   |   |--- inv-nodes <= 2.00
# |   |   |   |   |   |--- breast-quad <= 3.50
# |   |   |   |   |   |   |--- age <= 3.50
# |   |   |   |   |   |   |   |--- irradiat <= 0.50
# |   |   |   |   |   |   |   |   |--- node-caps <= 1.50
# |   |   |   |   |   |   |   |   |   |--- tumor-size <= 2.50
# |   |   |   |   |   |   |   |   |   |   |--- menopause <= 1.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: no-recurrence-events
# |   |   |   |   |   |   |   |   |   |   |--- menopause >  1.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: recurrence-events
# |   |   |   |   |   |   |   |   |   |--- tumor-size >  2.50
# |   |   |   |   |   |   |   |   |   |   |--- menopause <= 1.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- menopause >  1.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |--- node-caps >  1.50
# |   |   |   |   |   |   |   |   |   |--- class: no-recurrence-events
# |   |   |   |   |   |   |   |--- irradiat >  0.50
# |   |   |   |   |   |   |   |   |--- class: no-recurrence-events
# |   |   |   |   |   |   |--- age >  3.50
# |   |   |   |   |   |   |   |--- class: no-recurrence-events
# |   |   |   |   |   |--- breast-quad >  3.50
# |   |   |   |   |   |   |--- class: no-recurrence-events
# |   |   |   |   |--- inv-nodes >  2.00
# |   |   |   |   |   |--- menopause <= 1.00
# |   |   |   |   |   |   |--- inv-nodes <= 4.50
# |   |   |   |   |   |   |   |--- class: recurrence-events
# |   |   |   |   |   |   |--- inv-nodes >  4.50
# |   |   |   |   |   |   |   |--- irradiat <= 0.50
# |   |   |   |   |   |   |   |   |--- class: no-recurrence-events
# |   |   |   |   |   |   |   |--- irradiat >  0.50
# |   |   |   |   |   |   |   |   |--- class: recurrence-events
# |   |   |   |   |   |--- menopause >  1.00
# |   |   |   |   |   |   |--- age <= 2.50
# |   |   |   |   |   |   |   |--- inv-nodes <= 4.50
# |   |   |   |   |   |   |   |   |--- breast <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: recurrence-events
# |   |   |   |   |   |   |   |   |--- breast >  0.50
# |   |   |   |   |   |   |   |   |   |--- breast-quad <= 4.00
# |   |   |   |   |   |   |   |   |   |   |--- tumor-size <= 4.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: no-recurrence-events
# |   |   |   |   |   |   |   |   |   |   |--- tumor-size >  4.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: recurrence-events
# |   |   |   |   |   |   |   |   |   |--- breast-quad >  4.00
# |   |   |   |   |   |   |   |   |   |   |--- class: recurrence-events
# |   |   |   |   |   |   |   |--- inv-nodes >  4.50
# |   |   |   |   |   |   |   |   |--- age <= 1.50
# |   |   |   |   |   |   |   |   |   |--- inv-nodes <= 5.50
# |   |   |   |   |   |   |   |   |   |   |--- class: no-recurrence-events
# |   |   |   |   |   |   |   |   |   |--- inv-nodes >  5.50
# |   |   |   |   |   |   |   |   |   |   |--- class: recurrence-events
# |   |   |   |   |   |   |   |   |--- age >  1.50
# |   |   |   |   |   |   |   |   |   |--- class: no-recurrence-events
# |   |   |   |   |   |   |--- age >  2.50
# |   |   |   |   |   |   |   |--- class: no-recurrence-events
# |   |   |--- tumor-size >  6.50
# |   |   |   |--- inv-nodes <= 5.00
# |   |   |   |   |--- deg-malig <= 1.50
# |   |   |   |   |   |--- tumor-size <= 8.50
# |   |   |   |   |   |   |--- age <= 4.50
# |   |   |   |   |   |   |   |--- class: recurrence-events
# |   |   |   |   |   |   |--- age >  4.50
# |   |   |   |   |   |   |   |--- class: no-recurrence-events
# |   |   |   |   |   |--- tumor-size >  8.50
# |   |   |   |   |   |   |--- class: no-recurrence-events
# |   |   |   |   |--- deg-malig >  1.50
# |   |   |   |   |   |--- breast <= 0.50
# |   |   |   |   |   |   |--- class: no-recurrence-events
# |   |   |   |   |   |--- breast >  0.50
# |   |   |   |   |   |   |--- breast-quad <= 2.50
# |   |   |   |   |   |   |   |--- tumor-size <= 8.50
# |   |   |   |   |   |   |   |   |--- age <= 3.00
# |   |   |   |   |   |   |   |   |   |--- class: no-recurrence-events
# |   |   |   |   |   |   |   |   |--- age >  3.00
# |   |   |   |   |   |   |   |   |   |--- class: recurrence-events
# |   |   |   |   |   |   |   |--- tumor-size >  8.50
# |   |   |   |   |   |   |   |   |--- class: recurrence-events
# |   |   |   |   |   |   |--- breast-quad >  2.50
# |   |   |   |   |   |   |   |--- class: no-recurrence-events
# |   |   |   |--- inv-nodes >  5.00
# |   |   |   |   |--- class: recurrence-events
# |--- deg-malig >  2.50
# |   |--- node-caps <= 1.50
# |   |   |--- menopause <= 1.50
# |   |   |   |--- tumor-size <= 5.50
# |   |   |   |   |--- inv-nodes <= 5.00
# |   |   |   |   |   |--- inv-nodes <= 2.00
# |   |   |   |   |   |   |--- age <= 3.50
# |   |   |   |   |   |   |   |--- class: no-recurrence-events
# |   |   |   |   |   |   |--- age >  3.50
# |   |   |   |   |   |   |   |--- tumor-size <= 2.50
# |   |   |   |   |   |   |   |   |--- class: no-recurrence-events
# |   |   |   |   |   |   |   |--- tumor-size >  2.50
# |   |   |   |   |   |   |   |   |--- irradiat <= 0.50
# |   |   |   |   |   |   |   |   |   |--- age <= 4.50
# |   |   |   |   |   |   |   |   |   |   |--- tumor-size <= 3.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: recurrence-events
# |   |   |   |   |   |   |   |   |   |   |--- tumor-size >  3.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- age >  4.50
# |   |   |   |   |   |   |   |   |   |   |--- class: no-recurrence-events
# |   |   |   |   |   |   |   |   |--- irradiat >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: recurrence-events
# |   |   |   |   |   |--- inv-nodes >  2.00
# |   |   |   |   |   |   |--- class: recurrence-events
# |   |   |   |   |--- inv-nodes >  5.00
# |   |   |   |   |   |--- class: no-recurrence-events
# |   |   |   |--- tumor-size >  5.50
# |   |   |   |   |--- class: no-recurrence-events
# |   |   |--- menopause >  1.50
# |   |   |   |--- breast-quad <= 1.50
# |   |   |   |   |--- class: no-recurrence-events
# |   |   |   |--- breast-quad >  1.50
# |   |   |   |   |--- tumor-size <= 6.50
# |   |   |   |   |   |--- age <= 1.50
# |   |   |   |   |   |   |--- class: recurrence-events
# |   |   |   |   |   |--- age >  1.50
# |   |   |   |   |   |   |--- tumor-size <= 4.50
# |   |   |   |   |   |   |   |--- class: recurrence-events
# |   |   |   |   |   |   |--- tumor-size >  4.50
# |   |   |   |   |   |   |   |--- age <= 2.50
# |   |   |   |   |   |   |   |   |--- breast <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: no-recurrence-events
# |   |   |   |   |   |   |   |   |--- breast >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: recurrence-events
# |   |   |   |   |   |   |   |--- age >  2.50
# |   |   |   |   |   |   |   |   |--- class: recurrence-events
# |   |   |   |   |--- tumor-size >  6.50
# |   |   |   |   |   |--- class: no-recurrence-events
# |   |--- node-caps >  1.50
# |   |   |--- tumor-size <= 7.50
# |   |   |   |--- tumor-size <= 6.50
# |   |   |   |   |--- age <= 3.50
# |   |   |   |   |   |--- class: recurrence-events
# |   |   |   |   |--- age >  3.50
# |   |   |   |   |   |--- tumor-size <= 4.00
# |   |   |   |   |   |   |--- class: recurrence-events
# |   |   |   |   |   |--- tumor-size >  4.00
# |   |   |   |   |   |   |--- tumor-size <= 5.50
# |   |   |   |   |   |   |   |--- class: no-recurrence-events
# |   |   |   |   |   |   |--- tumor-size >  5.50
# |   |   |   |   |   |   |   |--- class: recurrence-events
# |   |   |   |--- tumor-size >  6.50
# |   |   |   |   |--- menopause <= 1.00
# |   |   |   |   |   |--- class: recurrence-events
# |   |   |   |   |--- menopause >  1.00
# |   |   |   |   |   |--- class: no-recurrence-events
# |   |   |--- tumor-size >  7.50
# |   |   |   |--- class: no-recurrence-events
#
# Goodness of Fit of Model 	Train Dataset
# Classification Accuracy 	: 0.9385964912280702
#
# Goodness of Fit of Model 	Test Dataset
# Classification Accuracy 	: 0.6842105263157895

# %%
#f1 score:
# print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_test_pred))
# Out:
#                       precision    recall  f1-score   support
#
# no-recurrence-events       0.78      0.78      0.78        41
#    recurrence-events       0.44      0.44      0.44        16
#
#             accuracy                           0.68        57
#            macro avg       0.61      0.61      0.61        57
#         weighted avg       0.68      0.68      0.68        57

# %% [markdown]
# ## GERMAN

# %%
german = pd.read_csv('german.csv', header = None)
german.head()

german_cols = german.iloc[0,:].tolist()
print(german_cols)
# german = german[0].str.split(" ", n = 20, expand = True)

german.columns = german_cols
german.to_csv("german.csv", index = None, header = True)
# Out:
# ['checkAccStatus', 'durationMth', 'credHist', 'purpose', 'credAmt', 'savAccBond', 'emplySince', 'instRate', 'personalStatSex', 'otherDebtGuar', 'presResSince', 'prpty', 'age(years)', 'otherInstallPlans', 'housing', 'numExistCreds', 'job', 'numPplMaintain', 'telephone', 'frgnWorker', 'goodBad']

# %%
german = german.drop(0,axis=0)
german.head()
# Out:
#   checkAccStatus durationMth credHist purpose credAmt savAccBond emplySince  \
# 1            A11           6      A34     A43    1169        A65        A75
# 2            A12          48      A32     A43    5951        A61        A73
# 3            A14          12      A34     A46    2096        A61        A74
# 4            A11          42      A32     A42    7882        A61        A74
# 5            A11          24      A33     A40    4870        A61        A73
#
#   instRate personalStatSex otherDebtGuar  ... prpty age(years)  \
# 1        4             A93          A101  ...  A121         67
# 2        2             A92          A101  ...  A121         22
# 3        2             A93          A101  ...  A121         49
# 4        2             A93          A103  ...  A122         45
# 5        3             A93          A101  ...  A124         53
#
#   otherInstallPlans housing numExistCreds   job numPplMaintain telephone  \
# 1              A143    A152             2  A173              1      A192
# 2              A143    A152             1  A173              1      A191
# 3              A143    A152             1  A172              2      A191
# 4              A143    A153             1  A173              2      A191
# 5              A143    A153             2  A173              2      A191
#
#   frgnWorker goodBad
# 1       A201       1
# 2       A201       2
# 3       A201       1
# 4       A201       1
# 5       A201       2
#
# [5 rows x 21 columns]

# %%
german['checkAccStatus'] = labelencoder.fit_transform(german['checkAccStatus'])

german['credHist'] = labelencoder.fit_transform(german['credHist'])
german['purpose'] = labelencoder.fit_transform(german['purpose'])
german['savAccBond'] = labelencoder.fit_transform(german['savAccBond'])
german['emplySince'] = labelencoder.fit_transform(german['emplySince'])
german['personalStatSex'] = labelencoder.fit_transform(german['personalStatSex'])
german['otherDebtGuar'] = labelencoder.fit_transform(german['otherDebtGuar'])
german['prpty'] = labelencoder.fit_transform(german['prpty'])
german['otherInstallPlans'] = labelencoder.fit_transform(german['otherInstallPlans'])
german['housing'] = labelencoder.fit_transform(german['housing'])
german['job'] = labelencoder.fit_transform(german['job'])
german['telephone'] = labelencoder.fit_transform(german['telephone'])
german['frgnWorker'] = labelencoder.fit_transform(german['frgnWorker'])

# %%
X = german[["checkAccStatus", "durationMth", "credHist", "purpose", "credAmt","savAccBond","emplySince","instRate","personalStatSex","otherDebtGuar","presResSince","prpty","age(years)","otherInstallPlans","housing","numExistCreds","job","numPplMaintain","telephone","frgnWorker"]]
y = german[['goodBad']]
cols = ["checkAccStatus", "durationMth", "credHist", "purpose", "credAmt","savAccBond","emplySince","instRate","personalStatSex","otherDebtGuar","presResSince","prpty","age(years)","otherInstallPlans","housing","numExistCreds","job","numPplMaintain","telephone","frgnWorker"]

# %%
X.head()
# Out:
#    checkAccStatus durationMth  credHist  purpose credAmt  savAccBond  \
# 1               0           6         4        4    1169           4
# 2               1          48         2        4    5951           0
# 3               3          12         4        7    2096           0
# 4               0          42         2        3    7882           0
# 5               0          24         3        0    4870           0
#
#    emplySince instRate  personalStatSex  otherDebtGuar presResSince  prpty  \
# 1           4        4                2              0            4      0
# 2           2        2                1              0            2      0
# 3           3        2                2              0            3      0
# 4           3        2                2              2            4      1
# 5           2        3                2              0            4      3
#
#   age(years)  otherInstallPlans  housing numExistCreds  job numPplMaintain  \
# 1         67                  2        1             2    2              1
# 2         22                  2        1             1    2              1
# 3         49                  2        1             1    1              2
# 4         45                  2        2             1    2              2
# 5         53                  2        2             2    2              2
#
#    telephone  frgnWorker
# 1          1           0
# 2          0           0
# 3          0           0
# 4          0           0
# 5          0           0

# %%
#duration month cannot convert string to float

#fitting
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 25, test_size = 0.2)

Xt, Xcv, Yt, Ycv = train_test_split(X_train,y_train, random_state = 25, test_size = 0.2)

decision_tree = DecisionTreeClassifier(criterion='gini')

decision_tree = decision_tree.fit(Xt,Yt)
r = export_text(decision_tree, feature_names=cols)
print(r)

#prediction
y_train_pred = decision_tree.predict(X_train)
y_test_pred = decision_tree.predict(X_test)

# Check the Goodness of Fit (on Train Data)
print("Goodness of Fit of Model \tTrain Dataset")
print("Classification Accuracy \t:", decision_tree.score(X_train, y_train))
print()

# Check the Goodness of Fit (on Test Data)
print("Goodness of Fit of Model \tTest Dataset")
print("Classification Accuracy \t:", decision_tree.score(X_test, y_test))
print()
# Out:
# |--- checkAccStatus <= 1.50
# |   |--- durationMth <= 22.50
# |   |   |--- credHist <= 1.50
# |   |   |   |--- personalStatSex <= 2.50
# |   |   |   |   |--- purpose <= 7.50
# |   |   |   |   |   |--- age(years) <= 23.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- age(years) >  23.50
# |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |--- purpose >  7.50
# |   |   |   |   |   |--- class: 1
# |   |   |   |--- personalStatSex >  2.50
# |   |   |   |   |--- class: 1
# |   |   |--- credHist >  1.50
# |   |   |   |--- credAmt <= 1373.00
# |   |   |   |   |--- prpty <= 1.50
# |   |   |   |   |   |--- durationMth <= 11.00
# |   |   |   |   |   |   |--- emplySince <= 2.50
# |   |   |   |   |   |   |   |--- job <= 1.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- job >  1.50
# |   |   |   |   |   |   |   |   |--- presResSince <= 3.50
# |   |   |   |   |   |   |   |   |   |--- durationMth <= 8.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- durationMth >  8.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- presResSince >  3.50
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |--- emplySince >  2.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- durationMth >  11.00
# |   |   |   |   |   |   |--- otherInstallPlans <= 1.50
# |   |   |   |   |   |   |   |--- credAmt <= 667.00
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- credAmt >  667.00
# |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |--- otherInstallPlans >  1.50
# |   |   |   |   |   |   |   |--- emplySince <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- emplySince >  0.50
# |   |   |   |   |   |   |   |   |--- otherDebtGuar <= 0.50
# |   |   |   |   |   |   |   |   |   |--- savAccBond <= 2.50
# |   |   |   |   |   |   |   |   |   |   |--- credHist <= 2.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- credHist >  2.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- savAccBond >  2.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- otherDebtGuar >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- prpty >  1.50
# |   |   |   |   |   |--- presResSince <= 3.50
# |   |   |   |   |   |   |--- telephone <= 0.50
# |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |--- telephone >  0.50
# |   |   |   |   |   |   |   |--- checkAccStatus <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- checkAccStatus >  0.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- presResSince >  3.50
# |   |   |   |   |   |   |--- durationMth <= 11.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- durationMth >  11.50
# |   |   |   |   |   |   |   |--- numPplMaintain <= 1.50
# |   |   |   |   |   |   |   |   |--- durationMth <= 13.50
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- durationMth >  13.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- numPplMaintain >  1.50
# |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |--- credAmt >  1373.00
# |   |   |   |   |--- credAmt <= 8724.50
# |   |   |   |   |   |--- credAmt <= 3861.00
# |   |   |   |   |   |   |--- age(years) <= 25.50
# |   |   |   |   |   |   |   |--- telephone <= 0.50
# |   |   |   |   |   |   |   |   |--- job <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- job >  0.50
# |   |   |   |   |   |   |   |   |   |--- prpty <= 1.50
# |   |   |   |   |   |   |   |   |   |   |--- personalStatSex <= 2.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- personalStatSex >  2.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- prpty >  1.50
# |   |   |   |   |   |   |   |   |   |   |--- durationMth <= 16.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- durationMth >  16.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |--- telephone >  0.50
# |   |   |   |   |   |   |   |   |--- prpty <= 1.50
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- prpty >  1.50
# |   |   |   |   |   |   |   |   |   |--- emplySince <= 1.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |--- emplySince >  1.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- age(years) >  25.50
# |   |   |   |   |   |   |   |--- age(years) <= 58.00
# |   |   |   |   |   |   |   |   |--- savAccBond <= 3.50
# |   |   |   |   |   |   |   |   |   |--- presResSince <= 1.50
# |   |   |   |   |   |   |   |   |   |   |--- numPplMaintain <= 1.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- numPplMaintain >  1.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |--- presResSince >  1.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- savAccBond >  3.50
# |   |   |   |   |   |   |   |   |   |--- housing <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |--- housing >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- age(years) >  58.00
# |   |   |   |   |   |   |   |   |--- age(years) <= 65.50
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- age(years) >  65.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- credAmt >  3861.00
# |   |   |   |   |   |   |--- checkAccStatus <= 0.50
# |   |   |   |   |   |   |   |--- instRate <= 1.50
# |   |   |   |   |   |   |   |   |--- otherInstallPlans <= 1.00
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- otherInstallPlans >  1.00
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- instRate >  1.50
# |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |--- checkAccStatus >  0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- credAmt >  8724.50
# |   |   |   |   |   |--- class: 2
# |   |--- durationMth >  22.50
# |   |   |--- savAccBond <= 1.50
# |   |   |   |--- credHist <= 0.50
# |   |   |   |   |--- class: 2
# |   |   |   |--- credHist >  0.50
# |   |   |   |   |--- purpose <= 0.50
# |   |   |   |   |   |--- instRate <= 2.50
# |   |   |   |   |   |   |--- age(years) <= 31.50
# |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |--- age(years) >  31.50
# |   |   |   |   |   |   |   |--- emplySince <= 3.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- emplySince >  3.50
# |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |--- instRate >  2.50
# |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |--- purpose >  0.50
# |   |   |   |   |   |--- credAmt <= 7973.50
# |   |   |   |   |   |   |--- purpose <= 2.50
# |   |   |   |   |   |   |   |--- durationMth <= 46.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- durationMth >  46.50
# |   |   |   |   |   |   |   |   |--- job <= 2.50
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- job >  2.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- purpose >  2.50
# |   |   |   |   |   |   |   |--- credHist <= 3.50
# |   |   |   |   |   |   |   |   |--- age(years) <= 25.00
# |   |   |   |   |   |   |   |   |   |--- presResSince <= 3.00
# |   |   |   |   |   |   |   |   |   |   |--- numExistCreds <= 1.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- numExistCreds >  1.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |--- presResSince >  3.00
# |   |   |   |   |   |   |   |   |   |   |--- age(years) <= 23.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |   |--- age(years) >  23.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- age(years) >  25.00
# |   |   |   |   |   |   |   |   |   |--- job <= 2.50
# |   |   |   |   |   |   |   |   |   |   |--- credAmt <= 7783.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- credAmt >  7783.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- job >  2.50
# |   |   |   |   |   |   |   |   |   |   |--- otherInstallPlans <= 1.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |   |--- otherInstallPlans >  1.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- credHist >  3.50
# |   |   |   |   |   |   |   |   |--- purpose <= 5.50
# |   |   |   |   |   |   |   |   |   |--- age(years) <= 26.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |--- age(years) >  26.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- purpose >  5.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- credAmt >  7973.50
# |   |   |   |   |   |   |--- age(years) <= 51.00
# |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |--- age(years) >  51.00
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |--- savAccBond >  1.50
# |   |   |   |--- checkAccStatus <= 0.50
# |   |   |   |   |--- prpty <= 1.50
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- prpty >  1.50
# |   |   |   |   |   |--- otherInstallPlans <= 0.50
# |   |   |   |   |   |   |--- credAmt <= 1939.50
# |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |--- credAmt >  1939.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- otherInstallPlans >  0.50
# |   |   |   |   |   |   |--- class: 2
# |   |   |   |--- checkAccStatus >  0.50
# |   |   |   |   |--- credAmt <= 12296.50
# |   |   |   |   |   |--- housing <= 0.50
# |   |   |   |   |   |   |--- prpty <= 2.50
# |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |--- prpty >  2.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- housing >  0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- credAmt >  12296.50
# |   |   |   |   |   |--- class: 2
# |--- checkAccStatus >  1.50
# |   |--- emplySince <= 1.50
# |   |   |--- credAmt <= 6708.00
# |   |   |   |--- otherDebtGuar <= 0.50
# |   |   |   |   |--- purpose <= 5.50
# |   |   |   |   |   |--- credHist <= 1.00
# |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |--- credHist >  1.00
# |   |   |   |   |   |   |--- checkAccStatus <= 2.50
# |   |   |   |   |   |   |   |--- purpose <= 3.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- purpose >  3.50
# |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |--- checkAccStatus >  2.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- purpose >  5.50
# |   |   |   |   |   |--- prpty <= 0.50
# |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |--- prpty >  0.50
# |   |   |   |   |   |   |--- prpty <= 1.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- prpty >  1.50
# |   |   |   |   |   |   |   |--- age(years) <= 30.00
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- age(years) >  30.00
# |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |--- otherDebtGuar >  0.50
# |   |   |   |   |--- class: 2
# |   |   |--- credAmt >  6708.00
# |   |   |   |--- class: 2
# |   |--- emplySince >  1.50
# |   |   |--- otherInstallPlans <= 0.50
# |   |   |   |--- purpose <= 0.50
# |   |   |   |   |--- numExistCreds <= 1.50
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- numExistCreds >  1.50
# |   |   |   |   |   |--- class: 2
# |   |   |   |--- purpose >  0.50
# |   |   |   |   |--- housing <= 0.50
# |   |   |   |   |   |--- job <= 2.00
# |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |--- job >  2.00
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- housing >  0.50
# |   |   |   |   |   |--- purpose <= 5.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- purpose >  5.50
# |   |   |   |   |   |   |--- credAmt <= 1056.00
# |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |--- credAmt >  1056.00
# |   |   |   |   |   |   |   |--- personalStatSex <= 0.50
# |   |   |   |   |   |   |   |   |--- prpty <= 1.00
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- prpty >  1.00
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- personalStatSex >  0.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |--- otherInstallPlans >  0.50
# |   |   |   |--- numExistCreds <= 2.50
# |   |   |   |   |--- housing <= 1.50
# |   |   |   |   |   |--- age(years) <= 22.50
# |   |   |   |   |   |   |--- age(years) <= 21.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- age(years) >  21.50
# |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |--- age(years) >  22.50
# |   |   |   |   |   |   |--- otherDebtGuar <= 1.50
# |   |   |   |   |   |   |   |--- savAccBond <= 1.50
# |   |   |   |   |   |   |   |   |--- savAccBond <= 0.50
# |   |   |   |   |   |   |   |   |   |--- numPplMaintain <= 1.50
# |   |   |   |   |   |   |   |   |   |   |--- job <= 2.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- job >  2.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- numPplMaintain >  1.50
# |   |   |   |   |   |   |   |   |   |   |--- age(years) <= 34.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |   |--- age(years) >  34.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- savAccBond >  0.50
# |   |   |   |   |   |   |   |   |   |--- credAmt <= 1803.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- credAmt >  1803.50
# |   |   |   |   |   |   |   |   |   |   |--- age(years) <= 28.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- age(years) >  28.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |--- savAccBond >  1.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- otherDebtGuar >  1.50
# |   |   |   |   |   |   |   |--- presResSince <= 3.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- presResSince >  3.50
# |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |--- housing >  1.50
# |   |   |   |   |   |--- credAmt <= 11578.50
# |   |   |   |   |   |   |--- otherInstallPlans <= 1.50
# |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |--- otherInstallPlans >  1.50
# |   |   |   |   |   |   |   |--- durationMth <= 13.50
# |   |   |   |   |   |   |   |   |--- telephone <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- telephone >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- durationMth >  13.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- credAmt >  11578.50
# |   |   |   |   |   |   |--- class: 2
# |   |   |   |--- numExistCreds >  2.50
# |   |   |   |   |--- presResSince <= 3.50
# |   |   |   |   |   |--- class: 2
# |   |   |   |   |--- presResSince >  3.50
# |   |   |   |   |   |--- class: 1
#
# Goodness of Fit of Model 	Train Dataset
# Classification Accuracy 	: 0.9325
#
# Goodness of Fit of Model 	Test Dataset
# Classification Accuracy 	: 0.71

# %%
#f1 score:
# print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.78      0.81      0.80       140
#            2       0.52      0.48      0.50        60
#
#     accuracy                           0.71       200
#    macro avg       0.65      0.65      0.65       200
# weighted avg       0.70      0.71      0.71       200

# %% [markdown]
# ## HEART

# %%
heart = pd.read_csv('heart.csv', header = None)
# heart.head()


heart_cols = heart.iloc[0,:].tolist()

heart.columns = heart_cols
heart.to_csv("heart.csv", index = None, header = True)

heart = heart.drop(0,axis=0)
heart.head()
# Out:
#     age  sex chest pain type resting blood pressure serum cholesterol (mg/dl)  \
# 1  70.0  1.0             4.0                  130.0                     322.0
# 2  67.0  0.0             3.0                  115.0                     564.0
# 3  57.0  1.0             2.0                  124.0                     261.0
# 4  64.0  1.0             4.0                  128.0                     263.0
# 5  74.0  0.0             2.0                  120.0                     269.0
#
#   resting blood sugar >120mg/dl resting electrocariographic results  \
# 1                           0.0                                 2.0
# 2                           0.0                                 2.0
# 3                           0.0                                 0.0
# 4                           0.0                                 0.0
# 5                           0.0                                 2.0
#
#   maximum heart rate received exercise induced angina oldpeak slopePeak  \
# 1                       109.0                     0.0     2.4       2.0
# 2                       160.0                     0.0     1.6       2.0
# 3                       141.0                     0.0     0.3       1.0
# 4                       105.0                     1.0     0.2       2.0
# 5                       121.0                     1.0     0.2       1.0
#
#   numMajorVessels thal class
# 1             3.0  3.0     2
# 2             0.0  7.0     1
# 3             0.0  7.0     2
# 4             1.0  7.0     1
# 5             1.0  3.0     1

# %%
X = heart[["age", "sex", "chest pain type", "resting blood pressure", "serum cholesterol (mg/dl)", "resting blood sugar >120mg/dl","resting electrocariographic results","maximum heart rate received","exercise induced angina", "oldpeak","slopePeak", "numMajorVessels","thal"]]
y = heart[['class']]
cols = ["age", "sex", "chest pain type", "resting blood pressure", "serum cholesterol (mg/dl)", "resting blood sugar >120mg/dl","resting electrocariographic results","maximum heart rate received","exercise induced angina", "oldpeak","slopePeak", "numMajorVessels","thal"]

# %%
#fitting
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 25, test_size = 0.2)

Xt, Xcv, Yt, Ycv = train_test_split(X_train,y_train, random_state = 25, test_size = 0.2)

decision_tree = DecisionTreeClassifier(criterion='gini')

decision_tree = decision_tree.fit(Xt,Yt)
r = export_text(decision_tree, feature_names=cols)
print(r)

#prediction
y_train_pred = decision_tree.predict(X_train)
y_test_pred = decision_tree.predict(X_test)

# Check the Goodness of Fit (on Train Data)
print("Goodness of Fit of Model \tTrain Dataset")
print("Classification Accuracy \t:", decision_tree.score(X_train, y_train))
print()

# Check the Goodness of Fit (on Test Data)
print("Goodness of Fit of Model \tTest Dataset")
print("Classification Accuracy \t:", decision_tree.score(X_test, y_test))
print()
# Out:
# |--- thal <= 4.50
# |   |--- chest pain type <= 3.50
# |   |   |--- oldpeak <= 2.50
# |   |   |   |--- serum cholesterol (mg/dl) <= 154.50
# |   |   |   |   |--- class: 2
# |   |   |   |--- serum cholesterol (mg/dl) >  154.50
# |   |   |   |   |--- serum cholesterol (mg/dl) <= 330.00
# |   |   |   |   |   |--- resting blood pressure <= 109.00
# |   |   |   |   |   |   |--- maximum heart rate received <= 156.00
# |   |   |   |   |   |   |   |--- serum cholesterol (mg/dl) <= 232.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- serum cholesterol (mg/dl) >  232.50
# |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |--- maximum heart rate received >  156.00
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- resting blood pressure >  109.00
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- serum cholesterol (mg/dl) >  330.00
# |   |   |   |   |   |--- sex <= 0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- sex >  0.50
# |   |   |   |   |   |   |--- class: 2
# |   |   |--- oldpeak >  2.50
# |   |   |   |--- slopePeak <= 2.50
# |   |   |   |   |--- class: 2
# |   |   |   |--- slopePeak >  2.50
# |   |   |   |   |--- class: 1
# |   |--- chest pain type >  3.50
# |   |   |--- numMajorVessels <= 0.50
# |   |   |   |--- maximum heart rate received <= 119.50
# |   |   |   |   |--- class: 2
# |   |   |   |--- maximum heart rate received >  119.50
# |   |   |   |   |--- resting blood pressure <= 154.00
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- resting blood pressure >  154.00
# |   |   |   |   |   |--- exercise induced angina <= 0.50
# |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |--- exercise induced angina >  0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |--- numMajorVessels >  0.50
# |   |   |   |--- resting blood pressure <= 107.00
# |   |   |   |   |--- class: 1
# |   |   |   |--- resting blood pressure >  107.00
# |   |   |   |   |--- serum cholesterol (mg/dl) <= 296.50
# |   |   |   |   |   |--- class: 2
# |   |   |   |   |--- serum cholesterol (mg/dl) >  296.50
# |   |   |   |   |   |--- serum cholesterol (mg/dl) <= 303.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- serum cholesterol (mg/dl) >  303.50
# |   |   |   |   |   |   |--- class: 2
# |--- thal >  4.50
# |   |--- chest pain type <= 3.50
# |   |   |--- maximum heart rate received <= 146.50
# |   |   |   |--- class: 2
# |   |   |--- maximum heart rate received >  146.50
# |   |   |   |--- resting blood pressure <= 176.00
# |   |   |   |   |--- oldpeak <= 2.40
# |   |   |   |   |   |--- maximum heart rate received <= 152.00
# |   |   |   |   |   |   |--- serum cholesterol (mg/dl) <= 231.00
# |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |--- serum cholesterol (mg/dl) >  231.00
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- maximum heart rate received >  152.00
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- oldpeak >  2.40
# |   |   |   |   |   |--- class: 2
# |   |   |   |--- resting blood pressure >  176.00
# |   |   |   |   |--- class: 2
# |   |--- chest pain type >  3.50
# |   |   |--- oldpeak <= 0.55
# |   |   |   |--- slopePeak <= 1.50
# |   |   |   |   |--- maximum heart rate received <= 133.50
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- maximum heart rate received >  133.50
# |   |   |   |   |   |--- class: 2
# |   |   |   |--- slopePeak >  1.50
# |   |   |   |   |--- class: 1
# |   |   |--- oldpeak >  0.55
# |   |   |   |--- serum cholesterol (mg/dl) <= 202.00
# |   |   |   |   |--- serum cholesterol (mg/dl) <= 200.50
# |   |   |   |   |   |--- class: 2
# |   |   |   |   |--- serum cholesterol (mg/dl) >  200.50
# |   |   |   |   |   |--- class: 1
# |   |   |   |--- serum cholesterol (mg/dl) >  202.00
# |   |   |   |   |--- class: 2
#
# Goodness of Fit of Model 	Train Dataset
# Classification Accuracy 	: 0.9490740740740741
#
# Goodness of Fit of Model 	Test Dataset
# Classification Accuracy 	: 0.7592592592592593

# %%
#f1 score:
# print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.72      0.85      0.78        27
#            2       0.82      0.67      0.73        27
#
#     accuracy                           0.76        54
#    macro avg       0.77      0.76      0.76        54
# weighted avg       0.77      0.76      0.76        54

# %% [markdown]
# ## STROKE

# %%
stroke = pd.read_csv("healthcare-dataset-stroke-data.csv", sep=",")
stroke.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
stroke['gender'] = labelencoder.fit_transform(stroke['gender'])
stroke['ever_married'] = labelencoder.fit_transform(stroke['ever_married'])
stroke['work_type'] = labelencoder.fit_transform(stroke['work_type'])
stroke['Residence_type'] = labelencoder.fit_transform(stroke['Residence_type'])
stroke['smoking_status'] = labelencoder.fit_transform(stroke['smoking_status'])

# for col in stroke.columns:
#   stroke[col] = stroke[col].fillna(0)
stroke = stroke.dropna()

# %%
X=stroke[["gender", "age", "heart_disease", "ever_married", "work_type","Residence_type","avg_glucose_level","bmi","smoking_status"]]
y=stroke[["stroke"]]
cols = ["gender", "age", "heart_disease", "ever_married", "work_type","Residence_type","avg_glucose_level","bmi","smoking_status"]

# %%
#fitting
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 25, test_size = 0.2)

Xt, Xcv, Yt, Ycv = train_test_split(X_train,y_train, random_state = 25, test_size = 0.2)

decision_tree = DecisionTreeClassifier(criterion='gini')

decision_tree = decision_tree.fit(Xt,Yt)
r = export_text(decision_tree, feature_names=cols)
print(r)

#prediction
y_train_pred = decision_tree.predict(X_train)
y_test_pred = decision_tree.predict(X_test)

# Check the Goodness of Fit (on Train Data)
print("Goodness of Fit of Model \tTrain Dataset")
print("Classification Accuracy \t:", decision_tree.score(X_train, y_train))
print()

# Check the Goodness of Fit (on Test Data)
print("Goodness of Fit of Model \tTest Dataset")
print("Classification Accuracy \t:", decision_tree.score(X_test, y_test))
print()
# Out:
# |--- age <= 67.50
# |   |--- age <= 48.50
# |   |   |--- age <= 37.50
# |   |   |   |--- avg_glucose_level <= 57.93
# |   |   |   |   |--- avg_glucose_level <= 57.92
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- avg_glucose_level >  57.92
# |   |   |   |   |   |--- class: 1
# |   |   |   |--- avg_glucose_level >  57.93
# |   |   |   |   |--- smoking_status <= 2.50
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- smoking_status >  2.50
# |   |   |   |   |   |--- avg_glucose_level <= 76.23
# |   |   |   |   |   |   |--- avg_glucose_level <= 75.81
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- avg_glucose_level >  75.81
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- avg_glucose_level >  76.23
# |   |   |   |   |   |   |--- class: 0
# |   |   |--- age >  37.50
# |   |   |   |--- avg_glucose_level <= 86.97
# |   |   |   |   |--- avg_glucose_level <= 86.94
# |   |   |   |   |   |--- bmi <= 26.35
# |   |   |   |   |   |   |--- bmi <= 26.10
# |   |   |   |   |   |   |   |--- age <= 47.50
# |   |   |   |   |   |   |   |   |--- avg_glucose_level <= 82.26
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- avg_glucose_level >  82.26
# |   |   |   |   |   |   |   |   |   |--- ever_married <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- ever_married >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- smoking_status <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- smoking_status >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- age >  47.50
# |   |   |   |   |   |   |   |   |--- avg_glucose_level <= 74.14
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- avg_glucose_level >  74.14
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- bmi >  26.10
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- bmi >  26.35
# |   |   |   |   |   |   |--- avg_glucose_level <= 64.16
# |   |   |   |   |   |   |   |--- avg_glucose_level <= 64.06
# |   |   |   |   |   |   |   |   |--- bmi <= 38.15
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- bmi >  38.15
# |   |   |   |   |   |   |   |   |   |--- bmi <= 39.40
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- bmi >  39.40
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- avg_glucose_level >  64.06
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- avg_glucose_level >  64.16
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- avg_glucose_level >  86.94
# |   |   |   |   |   |--- class: 1
# |   |   |   |--- avg_glucose_level >  86.97
# |   |   |   |   |--- bmi <= 45.70
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- bmi >  45.70
# |   |   |   |   |   |--- bmi <= 46.05
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- bmi >  46.05
# |   |   |   |   |   |   |--- class: 0
# |   |--- age >  48.50
# |   |   |--- heart_disease <= 0.50
# |   |   |   |--- avg_glucose_level <= 86.15
# |   |   |   |   |--- avg_glucose_level <= 76.47
# |   |   |   |   |   |--- avg_glucose_level <= 76.41
# |   |   |   |   |   |   |--- age <= 66.50
# |   |   |   |   |   |   |   |--- avg_glucose_level <= 76.10
# |   |   |   |   |   |   |   |   |--- age <= 54.50
# |   |   |   |   |   |   |   |   |   |--- bmi <= 28.45
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- bmi >  28.45
# |   |   |   |   |   |   |   |   |   |   |--- bmi <= 28.60
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- bmi >  28.60
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |--- age >  54.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- avg_glucose_level >  76.10
# |   |   |   |   |   |   |   |   |--- bmi <= 27.60
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- bmi >  27.60
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- age >  66.50
# |   |   |   |   |   |   |   |--- smoking_status <= 2.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- smoking_status >  2.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- avg_glucose_level >  76.41
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- avg_glucose_level >  76.47
# |   |   |   |   |   |--- class: 0
# |   |   |   |--- avg_glucose_level >  86.15
# |   |   |   |   |--- avg_glucose_level <= 86.33
# |   |   |   |   |   |--- smoking_status <= 1.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- smoking_status >  1.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- avg_glucose_level >  86.33
# |   |   |   |   |   |--- bmi <= 25.55
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- bmi >  25.55
# |   |   |   |   |   |   |--- bmi <= 40.35
# |   |   |   |   |   |   |   |--- bmi <= 27.45
# |   |   |   |   |   |   |   |   |--- bmi <= 27.25
# |   |   |   |   |   |   |   |   |   |--- avg_glucose_level <= 97.45
# |   |   |   |   |   |   |   |   |   |   |--- bmi <= 26.45
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- bmi >  26.45
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- avg_glucose_level >  97.45
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- bmi >  27.25
# |   |   |   |   |   |   |   |   |   |--- age <= 55.50
# |   |   |   |   |   |   |   |   |   |   |--- avg_glucose_level <= 105.51
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- avg_glucose_level >  105.51
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- age >  55.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- bmi >  27.45
# |   |   |   |   |   |   |   |   |--- ever_married <= 0.50
# |   |   |   |   |   |   |   |   |   |--- bmi <= 31.80
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- bmi >  31.80
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- ever_married >  0.50
# |   |   |   |   |   |   |   |   |   |--- avg_glucose_level <= 102.10
# |   |   |   |   |   |   |   |   |   |   |--- bmi <= 28.45
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- bmi >  28.45
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- avg_glucose_level >  102.10
# |   |   |   |   |   |   |   |   |   |   |--- avg_glucose_level <= 102.19
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- avg_glucose_level >  102.19
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |--- bmi >  40.35
# |   |   |   |   |   |   |   |--- bmi <= 40.45
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- bmi >  40.45
# |   |   |   |   |   |   |   |   |--- age <= 62.50
# |   |   |   |   |   |   |   |   |   |--- avg_glucose_level <= 232.52
# |   |   |   |   |   |   |   |   |   |   |--- gender <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- gender >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- avg_glucose_level >  232.52
# |   |   |   |   |   |   |   |   |   |   |--- bmi <= 46.40
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- bmi >  46.40
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- age >  62.50
# |   |   |   |   |   |   |   |   |   |--- bmi <= 41.95
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- bmi >  41.95
# |   |   |   |   |   |   |   |   |   |   |--- smoking_status <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- smoking_status >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |--- heart_disease >  0.50
# |   |   |   |--- smoking_status <= 2.50
# |   |   |   |   |--- age <= 62.50
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- age >  62.50
# |   |   |   |   |   |--- bmi <= 29.20
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- bmi >  29.20
# |   |   |   |   |   |   |--- age <= 63.50
# |   |   |   |   |   |   |   |--- bmi <= 37.80
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- bmi >  37.80
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- age >  63.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |--- smoking_status >  2.50
# |   |   |   |   |--- bmi <= 35.70
# |   |   |   |   |   |--- avg_glucose_level <= 240.27
# |   |   |   |   |   |   |--- age <= 59.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- age >  59.50
# |   |   |   |   |   |   |   |--- age <= 61.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- age >  61.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- avg_glucose_level >  240.27
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- bmi >  35.70
# |   |   |   |   |   |--- class: 1
# |--- age >  67.50
# |   |--- age <= 76.50
# |   |   |--- avg_glucose_level <= 184.42
# |   |   |   |--- ever_married <= 0.50
# |   |   |   |   |--- age <= 68.50
# |   |   |   |   |   |--- avg_glucose_level <= 101.88
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- avg_glucose_level >  101.88
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- age >  68.50
# |   |   |   |   |   |--- heart_disease <= 0.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- heart_disease >  0.50
# |   |   |   |   |   |   |--- Residence_type <= 0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- Residence_type >  0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |--- ever_married >  0.50
# |   |   |   |   |--- smoking_status <= 0.50
# |   |   |   |   |   |--- gender <= 0.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- gender >  0.50
# |   |   |   |   |   |   |--- age <= 73.50
# |   |   |   |   |   |   |   |--- age <= 69.50
# |   |   |   |   |   |   |   |   |--- avg_glucose_level <= 93.01
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- avg_glucose_level >  93.01
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- age >  69.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- age >  73.50
# |   |   |   |   |   |   |   |--- avg_glucose_level <= 125.99
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- avg_glucose_level >  125.99
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- smoking_status >  0.50
# |   |   |   |   |   |--- avg_glucose_level <= 59.97
# |   |   |   |   |   |   |--- heart_disease <= 0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- heart_disease >  0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- avg_glucose_level >  59.97
# |   |   |   |   |   |   |--- bmi <= 27.35
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- bmi >  27.35
# |   |   |   |   |   |   |   |--- bmi <= 27.45
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- bmi >  27.45
# |   |   |   |   |   |   |   |   |--- Residence_type <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- Residence_type >  0.50
# |   |   |   |   |   |   |   |   |   |--- age <= 75.50
# |   |   |   |   |   |   |   |   |   |   |--- avg_glucose_level <= 89.40
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- avg_glucose_level >  89.40
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- age >  75.50
# |   |   |   |   |   |   |   |   |   |   |--- bmi <= 34.40
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- bmi >  34.40
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |--- avg_glucose_level >  184.42
# |   |   |   |--- bmi <= 32.70
# |   |   |   |   |--- smoking_status <= 2.50
# |   |   |   |   |   |--- ever_married <= 0.50
# |   |   |   |   |   |   |--- avg_glucose_level <= 209.35
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- avg_glucose_level >  209.35
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- ever_married >  0.50
# |   |   |   |   |   |   |--- Residence_type <= 0.50
# |   |   |   |   |   |   |   |--- bmi <= 28.80
# |   |   |   |   |   |   |   |   |--- bmi <= 28.55
# |   |   |   |   |   |   |   |   |   |--- gender <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- bmi <= 25.15
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- bmi >  25.15
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- gender >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- bmi >  28.55
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- bmi >  28.80
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- Residence_type >  0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- smoking_status >  2.50
# |   |   |   |   |   |--- avg_glucose_level <= 235.29
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- avg_glucose_level >  235.29
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |--- bmi >  32.70
# |   |   |   |   |--- avg_glucose_level <= 231.14
# |   |   |   |   |   |--- avg_glucose_level <= 196.65
# |   |   |   |   |   |   |--- age <= 71.50
# |   |   |   |   |   |   |   |--- work_type <= 2.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- work_type >  2.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- age >  71.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- avg_glucose_level >  196.65
# |   |   |   |   |   |   |--- bmi <= 45.60
# |   |   |   |   |   |   |   |--- age <= 68.50
# |   |   |   |   |   |   |   |   |--- bmi <= 38.35
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- bmi >  38.35
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- age >  68.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- bmi >  45.60
# |   |   |   |   |   |   |   |--- smoking_status <= 1.00
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- smoking_status >  1.00
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- avg_glucose_level >  231.14
# |   |   |   |   |   |--- work_type <= 2.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- work_type >  2.50
# |   |   |   |   |   |   |--- class: 0
# |   |--- age >  76.50
# |   |   |--- smoking_status <= 0.50
# |   |   |   |--- avg_glucose_level <= 133.97
# |   |   |   |   |--- avg_glucose_level <= 73.88
# |   |   |   |   |   |--- avg_glucose_level <= 68.26
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- avg_glucose_level >  68.26
# |   |   |   |   |   |   |--- age <= 79.00
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- age >  79.00
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- avg_glucose_level >  73.88
# |   |   |   |   |   |--- class: 0
# |   |   |   |--- avg_glucose_level >  133.97
# |   |   |   |   |--- avg_glucose_level <= 135.06
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- avg_glucose_level >  135.06
# |   |   |   |   |   |--- heart_disease <= 0.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- heart_disease >  0.50
# |   |   |   |   |   |   |--- avg_glucose_level <= 218.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- avg_glucose_level >  218.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |--- smoking_status >  0.50
# |   |   |   |--- avg_glucose_level <= 56.15
# |   |   |   |   |--- class: 1
# |   |   |   |--- avg_glucose_level >  56.15
# |   |   |   |   |--- avg_glucose_level <= 64.30
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- avg_glucose_level >  64.30
# |   |   |   |   |   |--- avg_glucose_level <= 67.56
# |   |   |   |   |   |   |--- avg_glucose_level <= 65.81
# |   |   |   |   |   |   |   |--- bmi <= 36.55
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- bmi >  36.55
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- avg_glucose_level >  65.81
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- avg_glucose_level >  67.56
# |   |   |   |   |   |   |--- bmi <= 34.15
# |   |   |   |   |   |   |   |--- bmi <= 30.75
# |   |   |   |   |   |   |   |   |--- age <= 78.50
# |   |   |   |   |   |   |   |   |   |--- ever_married <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- bmi <= 28.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- bmi >  28.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- ever_married >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- work_type <= 2.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- work_type >  2.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |--- age >  78.50
# |   |   |   |   |   |   |   |   |   |--- work_type <= 2.50
# |   |   |   |   |   |   |   |   |   |   |--- age <= 81.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- age >  81.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- work_type >  2.50
# |   |   |   |   |   |   |   |   |   |   |--- bmi <= 17.60
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- bmi >  17.60
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |--- bmi >  30.75
# |   |   |   |   |   |   |   |   |--- age <= 81.50
# |   |   |   |   |   |   |   |   |   |--- avg_glucose_level <= 207.16
# |   |   |   |   |   |   |   |   |   |   |--- bmi <= 33.10
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- bmi >  33.10
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- avg_glucose_level >  207.16
# |   |   |   |   |   |   |   |   |   |   |--- avg_glucose_level <= 255.22
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- avg_glucose_level >  255.22
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- age >  81.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- bmi >  34.15
# |   |   |   |   |   |   |   |--- avg_glucose_level <= 229.36
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- avg_glucose_level >  229.36
# |   |   |   |   |   |   |   |   |--- avg_glucose_level <= 233.55
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- avg_glucose_level >  233.55
# |   |   |   |   |   |   |   |   |   |--- class: 0
#
# Goodness of Fit of Model 	Train Dataset
# Classification Accuracy 	: 0.9852304558186911
#
# Goodness of Fit of Model 	Test Dataset
# Classification Accuracy 	: 0.9195519348268839

# %%
#f1 score:
# print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96       939
#            1       0.05      0.05      0.05        43
#
#     accuracy                           0.92       982
#    macro avg       0.50      0.50      0.50       982
# weighted avg       0.92      0.92      0.92       982

# %% [markdown]
# ## PLACEMENT

# %%
campusPlacement = pd.read_csv("Placement_Data_Full_Class.csv")
campusPlacement.head()
# Out:
#    sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0      1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1      2      M  79.33  Central  78.33   Others   Science     77.48
# 2      3      M  65.00  Central  68.00  Central      Arts     64.00
# 3      4      M  56.00  Central  52.00  Central   Science     52.00
# 4      5      M  85.80  Central  73.60  Central  Commerce     73.30
#
#     degree_t workex  etest_p specialisation  mba_p      status    salary
# 0   Sci&Tech     No     55.0         Mkt&HR  58.80      Placed  270000.0
# 1   Sci&Tech    Yes     86.5        Mkt&Fin  66.28      Placed  200000.0
# 2  Comm&Mgmt     No     75.0        Mkt&Fin  57.80      Placed  250000.0
# 3   Sci&Tech     No     66.0         Mkt&HR  59.43  Not Placed       NaN
# 4  Comm&Mgmt     No     96.8        Mkt&Fin  55.50      Placed  425000.0

# %%
campusPlacement['gender'] = labelencoder.fit_transform(campusPlacement['gender'])
campusPlacement['ssc_b'] = labelencoder.fit_transform(campusPlacement['ssc_b'])
campusPlacement['hsc_b'] = labelencoder.fit_transform(campusPlacement['hsc_b'])
campusPlacement['hsc_s'] = labelencoder.fit_transform(campusPlacement['hsc_s'])
campusPlacement['degree_t'] = labelencoder.fit_transform(campusPlacement['degree_t'])
campusPlacement['workex'] = labelencoder.fit_transform(campusPlacement['workex'])
campusPlacement['specialisation'] = labelencoder.fit_transform(campusPlacement['specialisation'])
campusPlacement['status'] = labelencoder.fit_transform(campusPlacement['status'])

# %%
X = campusPlacement[['sl_no', 'gender', 'ssc_p', 'ssc_b', 'hsc_p', 'hsc_b', 'hsc_s', 'degree_p', 'degree_t', 'workex', 'etest_p', 'specialisation', 'mba_p']]#, 'salary']]
y=campusPlacement[['status']]
cols = ['sl_no', 'gender', 'ssc_p', 'ssc_b', 'hsc_p', 'hsc_b', 'hsc_s', 'degree_p', 'degree_t', 'workex', 'etest_p', 'specialisation', 'mba_p']#, 'salary']

# %%
X = X.dropna()

#fitting
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 25, test_size = 0.2)

Xt, Xcv, Yt, Ycv = train_test_split(X_train,y_train, random_state = 25, test_size = 0.2)

decision_tree = DecisionTreeClassifier(criterion='gini')

decision_tree = decision_tree.fit(Xt,Yt)
r = export_text(decision_tree, feature_names=cols)
print(r)

#prediction
y_train_pred = decision_tree.predict(X_train)
y_test_pred = decision_tree.predict(X_test)

# Check the Goodness of Fit (on Train Data)
print("Goodness of Fit of Model \tTrain Dataset")
print("Classification Accuracy \t:", decision_tree.score(X_train, y_train))
print()

# Check the Goodness of Fit (on Test Data)
print("Goodness of Fit of Model \tTest Dataset")
print("Classification Accuracy \t:", decision_tree.score(X_test, y_test))
print()
# Out:
# |--- ssc_p <= 62.50
# |   |--- degree_p <= 64.40
# |   |   |--- mba_p <= 57.06
# |   |   |   |--- sl_no <= 62.00
# |   |   |   |   |--- class: 0
# |   |   |   |--- sl_no >  62.00
# |   |   |   |   |--- class: 1
# |   |   |--- mba_p >  57.06
# |   |   |   |--- class: 0
# |   |--- degree_p >  64.40
# |   |   |--- ssc_p <= 55.80
# |   |   |   |--- degree_p <= 70.65
# |   |   |   |   |--- degree_t <= 1.50
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- degree_t >  1.50
# |   |   |   |   |   |--- sl_no <= 132.00
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- sl_no >  132.00
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |--- degree_p >  70.65
# |   |   |   |   |--- class: 1
# |   |   |--- ssc_p >  55.80
# |   |   |   |--- class: 1
# |--- ssc_p >  62.50
# |   |--- ssc_p <= 70.75
# |   |   |--- degree_t <= 0.50
# |   |   |   |--- degree_p <= 61.20
# |   |   |   |   |--- degree_p <= 58.50
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- degree_p >  58.50
# |   |   |   |   |   |--- class: 0
# |   |   |   |--- degree_p >  61.20
# |   |   |   |   |--- degree_p <= 73.50
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- degree_p >  73.50
# |   |   |   |   |   |--- sl_no <= 70.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- sl_no >  70.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |--- degree_t >  0.50
# |   |   |   |--- ssc_p <= 69.75
# |   |   |   |   |--- ssc_p <= 65.00
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- ssc_p >  65.00
# |   |   |   |   |   |--- sl_no <= 173.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- sl_no >  173.50
# |   |   |   |   |   |   |--- etest_p <= 80.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- etest_p >  80.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |--- ssc_p >  69.75
# |   |   |   |   |--- class: 1
# |   |--- ssc_p >  70.75
# |   |   |--- hsc_b <= 0.50
# |   |   |   |--- hsc_p <= 67.00
# |   |   |   |   |--- mba_p <= 65.89
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- mba_p >  65.89
# |   |   |   |   |   |--- class: 0
# |   |   |   |--- hsc_p >  67.00
# |   |   |   |   |--- class: 1
# |   |   |--- hsc_b >  0.50
# |   |   |   |--- class: 1
#
# Goodness of Fit of Model 	Train Dataset
# Classification Accuracy 	: 0.9476744186046512
#
# Goodness of Fit of Model 	Test Dataset
# Classification Accuracy 	: 0.7906976744186046

# %%
#f1 score:
# print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.69      0.64      0.67        14
#            1       0.83      0.86      0.85        29
#
#     accuracy                           0.79        43
#    macro avg       0.76      0.75      0.76        43
# weighted avg       0.79      0.79      0.79        43
